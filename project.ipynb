# %%
import networkx as nx
import matplotlib.pyplot as plt
import pandas as pd

# %%
import seaborn as sns
from networkx import from_numpy_array
import os

# %%
from pathlib import Path  # import Path from pathlib module

directory = Path('/teamspace/studios/this_studio/BDC-Project/data/68')  # set directory path
data_list = []
for file in directory.iterdir():  
    if file.is_file():  # Check if it's a file
        print(file)
        data = pd.read_csv(file, header=None)
        data = data.to_numpy(data)
        data_list.append(data)
# Out:
# /teamspace/studios/this_studio/BDC-Project/data/68/sub-1_fc.csv
# /teamspace/studios/this_studio/BDC-Project/data/68/sub-1_sc.csv

# %%
# first - sub-1 fc.csv

# %%
fc = from_numpy_array(data_list[0],edge_attr = "weight")
sc = from_numpy_array(data_list[1],edge_attr = "weight")

# %%
nx.draw(graph, node_color='red', edge_color='black', node_size=0.5, font_size=0, width = 0.1, with_labels = False)

# %% [markdown]
#  ### Degree:
#   ### Clustering Coefficient
#  ### Global Efficiency:
# ### Cost:
#  ### Average Path Length:
#  ### Shortest Path: The minimum path length between any two non-adjacent nodes, is important for understanding the most efficient route for communication between them.
# ### Betweenness Centrality:
